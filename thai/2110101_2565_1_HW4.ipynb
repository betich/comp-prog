# %% [markdown]
# # การบ้านครั้งที่ 4: String & File Processing

# %% [markdown]
# ## <mark><font color=red>รายการปรับปรุง</font></mark>
#
# - `highlight_words(s, words)`
#
#  - ตัวอย่างสุดท้าย ผลต้องเป็น
#
#  a[3]<mark>มิใช่</mark>ลิสต์ คืนค่า<mark>มิใช่</mark><mark>print</mark> =<mark>มิใช่</mark>เปรียบเทียบ รัก<mark>มิใช่</mark>ดวง<mark>ดาว</mark>ที่พราวแสง
#
#  - สตริงทั้งหลายในลิสต์ `words` ไม่มีอันไหนเป็น prefix ของอันอื่น เช่น จะไม่มี `words = ['aaa', 'aa']`
#
#  - สตริงทั้งหลายในลิสต์ `words` จะไม่มีตัวอักษรที่ปรากฏใน escape sequence ของการกำหนดสีและ reset เช่น จะไม่มี `x 1 b [ 0 m`
#
# - เวลาเปิดไฟล์ให้ใช้ `open(filename, 'r', encoding='utf-8')`
#
# - `def color_text(s)` แก้เป็น `def color_text(s, color)`
# ---
# ## <mark><font color=green>**โบนัส**</font></mark> บวกคะแนนเพิ่ม 10% ให้ฟังก์ชันที่ทำได้
# 1. `display_tag_file()` สามารถแสดงสีให้ถูกต้องได้เมื่อ tag สี และ tag </> อยู่คนละบรรทัดกัน
#
# 2. `highlight_words(t, w)` สามารถ highlight ได้โดยไม่สนว่าเป็นตัวพิมพ์เล็กหรือตัวพิมพ์ใหญ่

# %% [markdown]
# **50 คะแนน**
#
# การบ้านนี้เป็นการฝึกในเรื่องการประมวลผลสตริงและการอ่านเขียนแฟ้มข้อมูล
#
# การแสดงผลบนหน้าจอที่ผ่านมาจะเป็นสีขาวดำ แต่เราสามารถแสดงผลให้ออกมามีสีได้โดยการใส่รหัส resI Escape Sequence ของสีที่ต้องการแสดงได้ โดยรหัสใช้รหัส <font color=blue>`'\033['`</font> ตามด้วยรหัสสีที่เป็น foreground และ background แล้วจบด้วย <font color=blue>`'m'`</font> โดยรหัสสีเป็นค่าจำนวนเต็มที่แสดงในตารางข้างล่าง
#
# | Color	| Foreground Code | Background Code |
# | --- | :-: | :-: |
# | Black | 30 | 40
# | Red | 31 | 41
# | Green | 32 | 42
# | Yellow | 33 | 43
# | Blue | 34 | 44
# | Magenta | 35 | 45
# | Cyan | 36	| 46
# | White | 37 | 47
# | highlight | | 103
#
# รหัส escape sequence ที่จะใช้ จะทำแบบง่ายๆ คือ ถ้าต้องการแสดงข้อความเป็น <font color=red>สีแดง</font> ก็จะเอา escape sequence ของสีแดง มาวางหน้าข้อความ แล้วก็เอารหัส reset `'\033[0m'` วางไวัหลังข้อความ
#
# color | escape sequence
# --- | ---
# red | `\033[;31m`
# green | `\033[;32m`
# blue | `\033[;34m`
# highlight | `\033[;103m`
# reset | `\033[0m`
#
# ถ้าต้องการให้ข้อความ 'Python' แสดงเป็นสีน้ำเงิน ก็เอารหัสสีน้ำเงินวางหน้าข้อความและรหัส reset วางหลังข้อความ เป็น `'\033[;34mPython\033[0m'` นิสิตสามารถทดลองได้โดยเอาคำสั่ง
#
# `print('\033[;34mPython\033[0m')` ไปลอง run ดูแล้วลองเปลี่ยนเลขหน้า `m` เป็นค่าอื่นๆ ดูได้

# %% [markdown]
# ### **ข้อแนะนำ**
#
# ถ้านิสิตใช้ Thonny ในการเขียนโปรแกรม ขอให้ไปปรับตั้งค่า Theme ให้เป็น Default Light หรือ Default Dark (อย่าใช้ IDE Classic เพราะเวลาแสดงผลข้อความปกติจะแสดงเป็นสีน้ำเงินทำให้ดูความแตกต่างได้ยาก)
#
# <img src="https://www.mycourseville.com/sites/all/modules/courseville/files/ckfinder/userfiles/607893822/images/thonny-dark.png" width=400>
#
# <img src="https://www.mycourseville.com/sites/all/modules/courseville/files/ckfinder/userfiles/607893822/images/thonny-light.png" width=400>
#
# ทั้งใน Google Colab และ Thonny ถ้าเป็น Dark theme จะดูง่ายกว่า

# %% [markdown]
# ## งานของนิสิต
#
# จงเขียนฟังก์ชันต่อไปนี้ให้สมบูรณ์ (ข้อละ 10 คะแนน)
#
# 1. **`red(w), green(w), blue(w), highlight(w)`** ที่คืนผลลัพธ์เป็นสตริงที่ครอบด้วยรหัสสีและรหัส reset ตามชื่อของฟังก์ชัน
#
# คำสั่ง | ผลที่แสดงทางหน้าจอ
# --- | ---
# `print('red text:', red('red text'), 'and normal text')` | red text: <font color=red>red text</font> and normal text
# `print('green text:', green('green text'), 'and normal text')` | green text: <font color=green>green text</font> and normal text
# `print('blue text:', blue('blue text'), 'and normal text')` | blue text: <font color=blue>blue text</font> and normal text
# `print('highlight text:', highlight('highlight text'), 'and normal text')` | highlight text: <mark>highlight text</mark> and normal text
#
# ---
# 2. **`color_text(s, color)`** คืนค่าเป็นสตริงที่ครอบด้วยรหัสสีและรหัส reset ตามชื่อสีตามที่ระบุใน `color` โดยจะมีแค่ 3 สีคือ `'red'`, `'green'` และ `'blue'` โดยชื่อสีสามารถเขียนได้ทั้งตัวเล็กหรือตัวใหญ่ ถ้า `color` เป็นค่าอื่นๆ ก็จะคืนเป็นสตริง s ที่ไม่มีสี
#
#  *ตัวอย่าง*
#
# คำสั่ง | ผลที่แสดงทางหน้าจอ
# --- | ---
# `print(color_text('This is red text', 'red')` | <font color=red>`This is red text`</font>
# `print(color_text('This is green text', 'GreeN')` | <font color=green>`This is green text`</font>
# `print(color_text('This is blue text', 'BLUE')` | <font color=blue>`This is blue text`</font>
# `print(color_text('This is yellow text', 'yellow')` | `This is yellow text`
#
# ---
# 3. **`color_tag(s)`** คืนค่าเป็นสตริงที่แสดงผลเป็นสีตาม tag ที่ครอบข้อความไว้ โดยข้อความ s จะขึ้นต้นด้วย tag `<red>, <green>, หรือ <blue>` และจบด้วย `</>` เสมอ คำว่า `red`, `green`, `blue` จะเป็นตัวพิมพ์เล็กเท่านั้น และ tag ที่ใส่มาจะมีแค่ `<red`>, `<green>`, `<blue>` เท่านั้น <font color=red>และจะไม่มี tag ที่เขียนซ้อนกัน</font> เช่น `<red>ABC <blue>DEF</> XYZ</>`
#
#  *ตัวอย่าง*
#
# คำสั่ง | ผลที่แสดงทางหน้าจอ
# --- | ---
# `print(color_tag('<red>red text</>')` | <font  color=red>`red text`</font>
# `print(color_tag('<green>green text</>')` | <font color=green>`green text`</font>
# `print(color_tag('<blue>blue text</>')` | <font color=blue>`blue text`</font>
#
# ---
# 4. **`highlight_words(s, words)`** `s` เป็นสตริง `words` เป็นลิสต์ของสตริง โดยฟังก์ชันนี้จะคืนค่าเป็นสตริงที่เวลาแสดงผลแล้วจะ highlight ข้อความทุกข้อความที่อยู่ใน `words`
#
#  Note:
#  - สตริงทั้งหลายในลิสต์ `words` ไม่มีอันไหนเป็น prefix ของอันอื่น เช่น จะไม่มี `words = ['aaa', 'aa']`
#  - สตริงทั้งหลายในลิสต์ `words` จะไม่มีตัวอักษรที่ปรากฏใน escape sequence ของการกำหนดสีและ reset เช่น จะไม่มี `x 1 b [ 0 m`
#
#  *ตัวอย่าง*
#
#  `t = 'a[3]มิใช่ลิสต์ คืนค่ามิใช่print =มิใช่เปรียบเทียบ รักมิใช่ดวงดาวที่พราวแสง'`
#
# คำสั่ง | ผลที่แสดงทางหน้าจอ
# --- | ---
# `print(highlight_words(t,['มิใช่']))` | a[3]<mark>มิใช่</mark>ลิสต์ คืนค่า<mark>มิใช่</mark>print =<mark>มิใช่</mark>เปรียบเทียบ รัก<mark>มิใช่</mark>ดวงดาวที่พราวแสง`
# `print(highlight_words(t,['ลิสต์']))` | a[3]มิใช่<mark>ลิสต์</mark> คืนค่ามิใช่print =มิใช่เปรียบเทียบ รักมิใช่ดวงดาวที่พราวแสง
# `print(highlight_words(t, []))` | a[3]มิใช่ลิสต์ คืนค่ามิใช่print =มิใช่เปรียบเทียบ รักมิใช่ดวงดาวที่พราวแสง
# `w = ['print', 'ดาว', 'มิใช่']`<br>`z = highlight_words(t, w)`<br>`print(z)` | a[3]<mark>มิใช่</mark>ลิสต์ คืนค่า<mark>มิใช่</mark><mark>print</mark> =<mark>มิใช่</mark>เปรียบเทียบ รัก<mark>มิใช่</mark>ดวง<mark>ดาว</mark>ที่พราวแสง
#
# ---
# 5. **`display_tag_file(filename)`** อ่านไฟล์ที่มี tag สีครอบข้อความต่างๆ ในไฟล์ไว้ แล้วแสดงผลออกมาทางหน้าจอให้มีสีตาม tag ที่ระบุไว้ tag สี และ tag `</>` จะอยู่ในบรรทัดเดียวกันเสมอ แต่ใน 1 บรรทัดอาจจะมีได้หลาย tag
#
#  Note: ตอนเปิดไฟล์แนะนำให้ใช้ `open('มหาจุฬาลงกรณ์-tag.txt', 'r', encoding='utf-8')`
#
# *ตัวอย่าง* ไฟล์ที่จะให้แสดงผล <a href="https://drive.google.com/file/d/1IRLqJzeG8vslpgNapzXPACRZJ01olLq5/view?usp=sharing">มหาจุฬาลงกรณ์-tag.txt</a>
#
# นิสิตสามารถ upload ไฟล์เพื่อให้ google colab อ่านไฟล์ได้หลายวิธี แต่วิธีที่ง่ายๆ ก็คือวิธีที่ 1 ตาม <a href="https://towardsdatascience.com/7-ways-to-load-external-data-into-google-colab-7ba73e7d5fc7">upload file to google colob</a>
#
# `display_tag_file('มหาจุฬาลงกรณ์-tag.txt')` จะแสดงผลเป็นเนื้อเพลงมหาจุฬาลงกรณ์ที่มีสีดังนี้
#
# น้ำใจน้องพี่<font color=red>สีชมพู</font> ทุกคนไม่รู้ลืมบูชา<br>
# พระคุณของแหล่งเรียนมา <font color=blue>จุฬาลงกรณ์</font><br>
# ขอทูนขอเทิด<font color=green>พระนาม</font>ไท พระคุณแนบไว้นิรันดร<br>
# ขอ<font color=red>องค์</font>พระเอื้อ<font color=blue>อาทร</font> หลั่งพรคุ้มครอง<br>
# <font color=green>นิสิต</font>พร้อมหน้า สัญญาประคอง<br>
# ความดีทุกอย่างต่างปอง ผยอง<font color=red>พระเกียรติ</font>เกริกไกร<br>
# ขอตรา<font color=red>พระเกี้ยว</font>ยั้งยืนยง <font color=green>นิสิต</font>ประสงค์เป็นธงชัย<br>
# ถาวรยศอยู่คู่ไทย เชิดชัย ชโย
#
# ---
# ## การส่งงาน
#   * Save a copy in Drive
#   * เปลี่ยนชื่อ Notebook ให้เป็น HW4_xxxxxxxxxx.ipynb โดย xxxxxxxxxx เป็นเลขประจำตัวนิสิต
#   * File -> Download -> Download .ipynb
#   * ส่งไฟล์ที่ดาวน์โหลดได้ใน MyCourseVille ก่อนเวลา <font color=red>**23:59 น. วันที่ 18 ตุลาคม 2565**</font>
#   * จะตรวจแฟ้ม .ipynb แฟ้มล่าสุดที่ส่งในระบบ MyCourseVille เท่านั้น
#
# <hr>
#
# ## <font color=red>สำคัญ: อ่านตรงนี้ด้วย</font>
# - ข้อห้าม
#  - ห้ามใช้ dict กับ set
#  - ห้าม import ใด ๆ
#  - ในฟังก์ชันต้องไม่ใช้ตัวแปรนอกฟังก์ชัน ยกเว้นตัวแปรที่ให้ไว้ก่อน (`RESET`, `RED`, `GREEN`, `BLUE`, `HIGHLIGHT`)
#  - ห้ามเปลี่ยนบรรทัด def ของฟังก์ชันที่ให้เขียน
#  - ในกรณีที่ฟังก์ชันมีการคืนค่า ฟังก์ชันต้องคืนข้อมูลและประเภทข้อมูลตามที่กำหนดเท่านั้น
#  - ห้ามเปลี่ยนบรรทัดแรกของ code cell
# - ส่งแฟ้ม .ipynb กี่ครั้งก็ได้ แต่จะตรวจแฟ้ม .ipynb **แฟ้มล่าสุด** เท่านั้น
# - <font color=red>ส่อทุจริต</font> เช่น
#   - ส่งโปรแกรมที่ผู้ส่งไม่สามารถอธิบายได้ว่า ใช้หลักการและทำงานอย่างไร
#   - หรือ ส่งโปรแกรมที่คล้ายกับโปรแกรมของผู้อื่นมาก ๆ (ไม่ว่าจะเป็นผู้ให้หรือผู้รับ จะตั้งใจหรือไม่ก็ตาม)
#   - ฉะนั้น
#     - ให้แน่ใจว่า ไม่ดูโปรแกรมของคนอื่น
#     - ให้แน่ใจว่า ไม่ได้ให้คนอื่นดูโปรแกรมของตัวเอง
#
# - หากพบว่า งานที่ส่งส่อทุจริต จะได้นิสิตจะได้ $0$ ใน<font color=red>การบ้านครั้งนี้ และการบ้านครั้งที่แล้ว ๆ</font>
# - จะตรวจให้คะแนน เมื่อ
#  - แฟ้มที่ส่งครั้งหลังสุดใน MyCourseVille เป็นแฟ้มที่ตั้งชื่อตามที่กำหนด และเป็นแฟ้มที่ได้จากการ File->Download->Download .ipynb เท่านั้น (ไม่ใช่แฟ้ม .py แล้วมา rename เป็น .ipynb)
#  - ฟังก์ชันที่เขียนส่งต้องอยู่ใน code cell สุดท้ายข้างล่างนี้
#  - บรรทัดแรกของ code cell สุดท้ายต้องขึ้นต้นด้วย `# HW4_String_File_Processing` ตามที่ให้ไป
#  - ไม่ทำในสิ่งที่ห้ามทำในข้อห้าม
#  - code cell สุดท้ายสามารถทำงานได้ (ไม่มี error)
#
# ---

# %%
# HW4_String_File_Processing (ไม่ลบหรือแก้ไขบรรทัดนี้ หรือเพิ่มอะไรก่อนบรรทัดนี้ โดยเด็ดขาด)

# - เขียนในเซลล์นี้เท่านั้น 
# - ถ้าต้องการเขียนฟังก์ชันเพิ่ม ก็เขียนในเซลล์นี้

# ตัวแปรต่อไปนี้เป็นตัวแปรที่กำหนดค่าสีเพื่อเอาไว้ใช้ในโปรแกรม (ห้ามแก้ไข)
RESET = '\033[0m'
RED = '\033[;31m'
GREEN = '\033[;32m'
BLUE = '\033[;34m'
HIGHLIGHT = '\033[;103m'

# ---------------------------------------------------
def red(s):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    return RED + s + RESET
# ---------------------------------------------------
def green(s):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    return GREEN + s + RESET
# ---------------------------------------------------
def blue(s):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    return BLUE + s + RESET
# ---------------------------------------------------
def highlight(s):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    return HIGHLIGHT + s + RESET
# ---------------------------------------------------
def color_text(s, color):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    if color.lower() == 'red':
        return red(s)
    elif color.lower() == 'green':
        return green(s)
    elif color.lower() == 'blue':
        return blue(s)
    else:
        return s
    
# ---------------------------------------------------
def color_tag(s):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    o = 0
    res = ""
    len_r = 4
    len_g = 6
    len_b = 5

    while o != -1 and o < len(s):
      idx_l = s.find('<', o)
      if idx_l != -1:
        idx_m = s.find('>', o)
        res += s[o:idx_l]
        idx_e = s.find('<', idx_m+1)
        if idx_m - idx_l == len_r:
          res += red(s[idx_m+1:idx_e])
        elif idx_m - idx_l == len_g:
          res += green(s[idx_m+1:idx_e])
        elif idx_m - idx_l == len_b:
          res += blue(s[idx_m+1:idx_e])
        o = idx_e+3
      else:
        res += s[o:]
        break
      
    return res
# ---------------------------------------------------
def highlight_words(s, words):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    for word in words:
      o = 0
      while o != -1 and o < len(s):
        s_i = s.lower().find(word.lower(), o)
        if s_i != -1:
          s = s[:s_i] + highlight(s[s_i:s_i+len(word)]) + s[s_i+len(word):]
          o = s_i+len(highlight(s[s_i:s_i+len(word)]))
        else:
          break
    return s
    
# ---------------------------------------------------
def display_tag_file(filename):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    f = open(filename, 'r', encoding='utf-8') 
    return color_tag(f.read())
# Out:
# red text

# %%
def red(s):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    return "{}{}{}".format(RED, s, RESET)
# ---------------------------------------------------
def green(s):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    return "{}{}{}".format(GREEN, s, RESET)
# ---------------------------------------------------
def blue(s):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    return "{}{}{}".format(BLUE, s, RESET)
# ---------------------------------------------------
def highlight(s):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    return "{}{}{}".format(HIGHLIGHT, s, RESET)
# ---------------------------------------------------
def color_text(s, color):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    if color.lower() == 'red':
        return red(s)
    elif color.lower() == 'green':
        return green(s)
    elif color.lower() == 'blue':
        return blue(s)
    else:
        return s
# ---------------------------------------------------
def color_tag(s):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    result = ""
    o = 0
    len_r = 4
    len_g = 6
    len_b = 5

    while o != -1 and o < len(s):
      l = s.find('<', o)
      if l != -1:
        p = s.find('>', o)
        result += s[o:l]
        q = s.find('<', p+1)
        # red
        if p - l == len_r:
          result += red(s[p+1:q])
        # green
        elif p - l == len_g:
          result += green(s[p+1:q])
        # blue
        elif p - l == len_b:
          result += blue(s[p+1:q])
        o = q+3
      else:
        # ไม่มี tag
        result += s[o:]
        break
      
    return result
# ---------------------------------------------------
def highlight_words(s, words):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    for word in words:
      o = 0
      while o != -1 and o < len(s):
        s_i = s.lower().find(word.lower(), o)
        if s_i != -1:
          s = s[:s_i] + highlight(s[s_i:s_i+len(word)]) + s[s_i+len(word):]
          o = s_i+len(highlight(s[s_i:s_i+len(word)]))
        else:
          break
    return s

# ---------------------------------------------------
def display_tag_file(filename):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    f1 = open(filename, 'r', encoding='utf-8') 
    return color_tag(f1.read())

# %%
# HW4_String_File_Processing (ไม่ลบหรือแก้ไขบรรทัดนี้ หรือเพิ่มอะไรก่อนบรรทัดนี้ โดยเด็ดขาด)

# - เขียนในเซลล์นี้เท่านั้น 
# - ถ้าต้องการเขียนฟังก์ชันเพิ่ม ก็เขียนในเซลล์นี้

# ตัวแปรต่อไปนี้เป็นตัวแปรที่กำหนดค่าสีเพื่อเอาไว้ใช้ในโปรแกรม (ห้ามแก้ไข)
RESET = '\033[0m'
RED = '\033[;31m'
GREEN = '\033[;32m'
BLUE = '\033[;34m'
HIGHLIGHT = '\033[;103m'

# ---------------------------------------------------
def red(s):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    return RED+s+RESET
# ---------------------------------------------------
def green(s):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    return GREEN+s+RESET
# ---------------------------------------------------
def blue(s):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    return BLUE+s+RESET
# ---------------------------------------------------
def highlight(s):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    return HIGHLIGHT+s+RESET
# ---------------------------------------------------
def color_text(s, color):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    color = color.lower()
    if color == 'red':
      return red(s)
    if color == 'green':
      return green(s)
    if color == 'blue':
      return blue(s)
    
    return s
# ---------------------------------------------------
def color_tag(s):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    len_r = 4
    len_g = 6
    len_b = 5
    o = 0
    # first = True
    res = ""

    while o != -1 and o < len(s):
      idx_l = s.find('<', o)
      if idx_l != -1:
        idx_m = s.find('>', o)
        res += s[o:idx_l]
        idx_e = s.find('<', idx_m+1)
        if idx_m - idx_l == len_r:
          res += red(s[idx_m+1:idx_e])
        elif idx_m - idx_l == len_g:
          res += green(s[idx_m+1:idx_e])
        elif idx_m - idx_l == len_b:
          res += blue(s[idx_m+1:idx_e])
        o = idx_e+3
        # print(o, len(s), idx_l, idx_e)
      else:
        # case of no tag
        res += s[o:]
        break
      
    return res

    

# ---------------------------------------------------
def highlight_words(s, words):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    for word in words:
      o = 0
      while o != -1 and o < len(s):
        s_i = s.lower().find(word.lower(), o)
        if s_i != -1:
          s = s[:s_i] + highlight(s[s_i:s_i+len(word)]) + s[s_i+len(word):]
          o = s_i+len(highlight(s[s_i:s_i+len(word)]))
        else:
          break
    return s
# ---------------------------------------------------
def display_tag_file(filename):
    # ลบบรรทัด pass แล้วเขียนโค้ดของนิสิตแทน
    file = open(filename, 'r', encoding='utf-8')
    return color_tag(file.read())

print('red text:', red('red text'), 'and normal text')
print('green text:', green('green text'), 'and normal text')
print('blue text:', blue('blue text'), 'and normal text')
print('highlight text:', highlight('highlight text'), 'and normal text')
print()
print(color_text('This is red text', 'red'))
print(color_text('This is green text', 'GreeN'))
print(color_text('This is blue text', 'BLUE'))
print(color_text('This is yellow text', 'yellow'))
print()
print(color_tag('<red>red text</>'))
print(color_tag('<green>green text</>'))
print(color_tag('<blue>blue text</>'))
print(color_tag('<red>red text</> <green>green text</>mmsdfasdfads <blue>blue text</>asdfasdasd dasfa'))
print()
t = 'a[3]มิใช่ลิสต์ คืนค่ามิใช่print =มิใช่เปรียบเทียบ รักมิใช่ดวงดาวที่พราวแสง'
print(highlight_words(t,['มิใช่']))
print(highlight_words(t,['ลิสต์']))
print(highlight_words(t, []))
w = ['print', 'ดาว', 'มิใช่']
z = highlight_words(t, w)
print(z)
print()
print(display_tag_file('/content/มหาจุฬาลงกรณ์-tag.txt'))
