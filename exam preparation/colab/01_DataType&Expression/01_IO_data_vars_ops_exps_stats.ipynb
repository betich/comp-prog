# %% [markdown]
# # **Basic I/O, Data types, Variables, Operators, Expressions, Statements**

# %% [markdown]
# ## Topics
# * Program structures
# * ``` print(…) ```
# * Variables
# * Data types
# * Type conversions
# * ``` input() ```
# * Arithmetic operations

# %% [markdown]
# ## Program structure and functional characteristics

# %%
import matplotlib.pyplot as plt
import math
n = int(input())		# data points
if n < 10:
       n = 10
x = []
y = []
for k in range(n):
	x.append(k*16*math.pi/n)
	y.append(0.1*k*math.sin(x[k]))
plt.plot(x, y)
plt.show()
# Out:
# 40

# %%
print(1E3)  # 1 * 10^3, 
print(1E-3)
# Out:
# 1000.0
# 0.001

# %% [markdown]
# ##Exercise 1-1.1: Type the following program in the following code box and try running it.
#
# ```
# import matplotlib.pyplot as plt
# import math
#
# n = 300   # data points
# if n < 10:
#   n = 10
# x = []
# y = []
# for k in range(n):
#   x.append(k*16*math.pi/n)
#   y.append(0.1*k*math.sin(x[k]))
# plt.plot(x, y)
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt
import math

n = 60
if n < 10:
    n = 10
x = []
y = []
for k in range(n):
    x.append(k*16*math.pi/n)
    y.append(0.1*k*math.sin(x[k]))
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Basic data types: String and Number

# %%
"Hello", 'Hello', "Hello Pyton", 'Hello Python', "12345", '12345', "", ''
# Out:
# ('Hello', 'Hello', 'Hello Pyton', 'Hello Python', '12345', '12345', '', '')

# %%
1234, 0, -1234.0, 1.5E-15
# Out:
# (1234, 0, -1234.0, 1.5e-15)

# %% [markdown]
# ## Operator: plus

# %% [markdown]
# Concatenation of strings

# %%
"Hello"+" "+"!", "1"+"1"
# Out:
# ('Hello !', '11')

# %%
print('Hello' + ' ' + 'Hawaii')
print('1' + '2' + '3')
# Out:
# Hello Hawaii
# 123

# %% [markdown]
# Addition for numbers

# %%
1+1, 1+1.0
# Out:
# (2, 2.0)

# %% [markdown]
# Bad example (run-time error)

# %%
"1"+'1'
# Out:
# '11'

# %% [markdown]
# ## ``` print(...) ```

# %%
print("Hello")
print("Python")
print("Hello" + " " + "Python")
print("a", "b", "c", 1, 2, 3)
print("1+1 =", (1+1))
# Out:
# Hello
# Python
# Hello Python
# a b c 1 2 3
# 1+1 = 2

# %% [markdown]
# ## Exercise 1-2.1: Shuffle the statements in the following code box and try running it to get interesting pictures.

# %%
print("(\_/)     ( ' o ') ")
print('(")_(")   ("")-("")')
print("          (”)….(”) ")
print('( •,•)     (")-(")  ')
# Out:
# (\_/)     ( ' o ')
# (")_(")   ("")-("")
#           (”)….(”)
# ( •,•)     (")-(")

# %% [markdown]
# ## Exercise 1-2.2: In the follwoing code box, write  ```print``` statements to display the message "This is easy" in the first line and display the value of 1.963 x 10^34 in the second line.

# %%
print("This is easy")
print("This","is","easy")
print('This' + ' ' + 'is' + ' ' + 'easy')
print(1.963e34)
# Out:
# This is easy
# This is easy
# This is easy
# 1.963e+34

# %% [markdown]
# ## Variables

# %%
x = 4         # integer
print(x)
x = 'four'    # string
print(x)
Y = 5
print(Y)
y = 'five'
print(Y)

D_1 = 'hello'

If = '22'
print(If)
# Out:
# 4
# four
# 5
# 5
# 22

# %%
first_name = "John"
and = "ABC"
# Out:
#   File "<ipython-input-6-099f35a319b8>", line 2
#     and = "ABC"
#       ^
# SyntaxError: invalid syntax

# %%
a = 1			
b = 2			
c = a			
d = c + b 	
d = d + 5
a, b, c, d
# Out:
# (1, 2, 1, 8)

# %% [markdown]
# ##Exercise 1-3.1: Write a Python code that will work as the comments below in the following code box.
#
# ```
# # Assign the value 123 to x
# # Assign the value 321 to y
# # Assign the sum of values of x and y to z
# #
# ```

# %%
x = 123
y = 321
z = x + y

# %% [markdown]
# ## Examples: Variables and data types

# %%
first_name = "Ranee"					# str
last_name  = "Campen"					# str
aka			= "Bella"						  # str
age		 	= 29								  # int
height     = 1.65							# float
is_single  = True							# bool, True or False
birth_date = [24, 12, 1989]				# list -> [day, month, year]
tv_series  = ["Roy Marn", "Plearn Boon", 
					 "Bubphe Sanniwat", "Krong Kam"]

print("Name:", first_name, last_name)
print("Age:", age)
print("Aka:", aka, "or", aka[0:4:1])
d = birth_date[0]
m = birth_date[1]
y = birth_date[2]
print("Born:", str(d)+"/"+str(m)+"/"+str(y))
# Out:
# Name: Ranee Campen
# Age: 29
# Aka: Bella or Bell
# Born: 24/12/1989

# %% [markdown]
# ##Exercise 1-4.1: Write a Python code that will work as the comments below in the following code box.
#
# ```
# # Assign the integer value 12 to m
# # Assign the floating-poing value 12 to x
# # Assign the string literal ABC to t
# # Assign the list value 7, 9, 5 to a
# #
# ```

# %%
m = 12
x = 12.0
t ='ABC' # t = "ABC"
a = [7, 9, 5]

# %% [markdown]
# ## Type conversions

# %%
s3 = '990'
n = int(s3)

# %%
s1 = "123"
s2 = " 456"
n = int(s1) + int(s2)         # 123 + 456 => 579
f = float(s1) + float(s2)     # 123.0 + 456.0 => 579.0
print(s1+s2, n, f)
print(s1+s2 + ", " + str(n) + "," + str(f))
# Out:
# 123 456 579 579.0
# 123 456, 579,579.0

# %%
a = int(1)              # a = 1
b = int(1.9)            # b = 1
c = int(1.9 + 0.5)      # 2.4 -> c = 2
d = float(1.1)          # d = 1.1
e = float(1)            # e = 1.0
f = str("string")       # f = "string"
print(a, b, c, d, e, f)
print(int(1.9) + int(0.5)) # 2 or 1
print(int(1.9))
print(int(0.5))
# Out:
# 1 1 2 1.1 1.0 string
# 1
# 1
# 0

# %%
x = float("1.0")
print(x)
# Out:
# 1.0

# %% [markdown]
# ##Exercise 1-5.1: Complete the Python code in the following code box that will work as the comments.

# %%
x = [1,2,3]
y = [4,5,6]
# Convert the type of x to string and 
# concatenate it to the string obtained from 
# converting the type of y to string.
# Store the final value in t.
#
t = str(x) + str(y)
print(t)
# Out:
# [1, 2, 3][4, 5, 6]

# %% [markdown]
# ## ``` input()``` accepts string from keyboard

# %%
name = input()
print(name + " is a very easy ")
print("We use " + name + " in our class.")
print ("Hello " + name + ".")
# Out:
# Java
# Java is a very easy
# We use Java in our class.
# Hello Java.

# %% [markdown]
# ## Accepting numeric input

# %%
x = input()
#d = float(x) # 4.0
perimeter = d + d + d + d
print("Perimeter of square =", perimeter)
# Out:
# 4
# Perimeter of square = 48.0

# %% [markdown]
# ## Basic arithmetic operations

# %%
x = float(input())
#d = float(x) # 4.0
#perimeter = d + d + d + d
perimeter = x + x + x + x
print("Perimeter of square =", perimeter)
# Out:
# 4
# Perimeter of square = 16.0

# %%
a, b, c, d, e, f, g

# %%
a = 5 + 2         # 7
b = 5 - 2         # 3
c = 5 * 2         # 10
d = 5 ** 2        # 25
e = 5 / 2         # 2.5
f = 5 // 2        # 2
g = 5 % 2         # 1

a,b,c = c,a,b     # a = 10
                  # b = 7
                  # c = 3
a,b = b,a         # Exchange a and b
print(a,b,c,d,e,f)
# Out:
# 7 10 3 25 2.5 2

# %% [markdown]
# ## Tips

# %%
a = float(input())
a = -a
b = int(a)
c = int(a + 0.5)
d = a - int(a)
d = a % 1
e = b % 10
f = b // 10 % 10
g = b // 10**4 % 10

h = input()
h = int(h)

# %% [markdown]
# ## Exercise: Celsius input, display Fahrenheit

# %%
celsius = float(input())
fahrenheit = celsius*9/5 + 32
print(celsius, fahrenheit)
# Out:
# 37
# 37.0 98.6

# %% [markdown]
# ## Augmented assignments

# %%
a = 10
a = a + 5			# 15
a = a - 1			# 14
a = a * 2			# 28
a = a % 10		# 8
a = a ** 2		# 64
a = a // 10		# 6
a
# Out:
# 6

# %%
a = 10
a += 5				# 15
a -= 1				# 14
a *= 2				# 28
a %= 10				# 8
a **= 2				# 64
a //= 10	
a
# Out:
# 6

# %% [markdown]
# ##Exercise 1-6.1: Write a Python code that will work as the comments below in the following code box.
#
# ```
# # Accept an input string and assign its value to variable grade.
# # Display the message ''I'll get"
# # followed by a space and the value of grade.
# #
# ```

# %%
grade = input()
print("I'll get", grade)
# Out:
# A
# I'll get A

# %% [markdown]
# ##Exercise 1-6.2: Write a Python code that will work as the comments below in the following code box.
#
# ```
# # Accept an input float and assign its value to variable h.
# # Accept an input **float** and assign its value to variable w.
# # h is the height of a traingle.
# # w is the base width of the traingle.
# # Display the area of the triangle.
# ```

# %% [markdown]
# ##Exercise 1-6.3: Write a Python code that will work as the comments below in the following code box.
#
# ```
# # Accept an input integer and assign its value to variable x.
# # Accept an input **float** and assign its value to variable y.
# # Assign value of x (raised) to the
# (power of) y (exponentiation) to z.
# # Assign the least significant digit of z to d.
# # Display d.
# ```

# %% [markdown]
# ##Exercise 1-6.4: Run the Python code in the following code box and try to understand how it works and what it displays.

# %%
print("5 / 2 =", 5/2)
print("5 // 2 =", 5//2)

print("4**2 =", 4**2)
print("4**0.5 =", 4**0.5) # math.sqrt(4)

print("9 % 24 =", 9%24)
print("(9+24) % 24 =", (9+24)%24)

print("(-1+24) % 24 =", (-1+24)%24)
print("-1 % 24 =", -1%24)

print("4.5 % 1 =", 4.5%1)

print("int(4.9) =", int(4.9))
print("int(-4.9) =", int(-4.9))
# Out:
# 5 / 2 = 2.5
# 5 // 2 = 2
# 4**2 = 16
# 4**0.5 = 2.0
# 9 % 24 = 9
# (9+24) % 24 = 9
# (-1+24) % 24 = 23
# -1 % 24 = 23
# 4.5 % 1 = 0.5
# int(4.9) = 4
# int(-4.9) = -4

# %% [markdown]
# ##```math``` module

# %%
import math

degree = float(input())
radian = degree * 3.14159 / 180
radian = degree * math.pi /180
radian = math.radians(degree)
s = math.sin(radian)
c = math.cos(radian)
g = math.log( 1E100, 10 )         # g = 100.0
print (s, c, g)
# Out:
# 45
# 0.7071067811865475 0.7071067811865476 100.0

# %% [markdown]
# ## Bult-in functions

# %%
a = abs(-2)               # a = 2
b = round(2/3, 2)         # b = 0.67
c = max([4, 1, 5, 3])     # c = 5
d = min([4, 1, 5, 3])     # d = 1
e = sum([4, 1, 5, 3])     # e = 13
f = len([4, 1, 5, 3])     # f = 4
g = str(1234)             # g = "1234"
h = int("123")            # h = 123
i = float("-123.4")       # j = -123.4
#j = ()
print(a, b, c, d, e, f, g, h, i, j)
# Out:
# built-in function
# 2 0.67 5 1 13 4 1234 123 -123.4 built-in function

# %% [markdown]
# ## Nesting different functions

# %%
x1 = input()
x2 = int(x1)
x3 = abs(x2)
x4 = 1 + x3
x5 = str(x4)
print("x5 = " + x5)
# Out:
# 2
# x5 = 3

# %%
print("x5 = " + str(1+abs(int(input()))))
# Out:
# 2
# x5 = 3

# %% [markdown]
# ##Exercise 1-7.1: Write a Python code that will work as the comments below in the following code box.
#
# ```
# # Accept an input integer and assign its value to variable m.
# # Accept an input integer and assign its value to variable k.
# # Increment m by k.
#
# # Accept an input string and assign its value to variable s.
# # Accept an input string and assign its value to variable t.
# # Append t to s.
#
#
# # Accept an input float and assign its value to variable d.
# # d is an angle degree.
# # Convert d to radian and assign it to r.
# # Assign value sin(r) to x
# # Assign the two-point precision value of x  to y.
# #
# ```

# %% [markdown]
# ## Operator precedence: ```2+3*4 =``` ?

# %%
2 * 3 + 8 / -(2 - 4) - 2**2**3
2 * 3 + 8 / -(-2) - 2**2**3
2 * 3 + 8 / -(-2) - 2**8
2 * 3 + 8 / -(-2) - 256
2 * 3 + 8 / 2 - 256
6 + 8 / 2 - 256
6 + 4.0 - 256
10.0 - 256

# %% [markdown]
# ##Exercise 1-8.1: Run the Python code in the following code box and try to understand how it works and what it displays.

# %%
print("2+3*4 =", 2+3*4)
print("(2+3)*4 =", (2+3)*4)
print("2+3*4//2%4-1 =", 2+3*4//2%4-1)
print("6/2*3 =", 6/2*3)
print("6/(2*3) =", 6/(2*3))
print("2**3**2 =", 2**3**2)
print("(2**3)**2 =", (2**3)**2)
print("-2*-4 =", -2*-4)
print("-2**4 =", -2**4)
print("(-2)**4 =", (-2)**4)

# %% [markdown]
# ## Example: area, circumference calculation

# %%
import math
radius = float(input())
area = math.pi * radius**2
circum = 2 *math.pi * radius
print("Area =", round(area, 2))
print("Circumference =", round(circum, 2))
# Out:
# 4.5
# Area = 63.62
# Circumference = 28.27

# %% [markdown]
# ## Example: student id to (faculty, year, degree)

# %%
stu_id = int(input())
print("Student ID:", stu_id)
fac_code = stu_id % 100                 # Two least significant digits
year_in = 2500 + stu_id//10**8          # From two most significant digits
deg_code = stu_id//10**7 % 10
print("Faculty code:", fac_code)
print("Enrollment year:", year_in)
print("Academic degree:", deg_code)
# Out:
# 6231020121
# Student ID: 6231020121
# Faculty code: 21
# Enrollment year: 2562
# Academic degree: 3

# %% [markdown]
# ### Show each digit of student id

# %%
sid = int(input())                       # sid, say, = 6231020121
d = sid % 10; print(d); sid //= 10 ;print(sid)     # 621102012
d = sid % 10; print(d); sid //= 10 ;print(sid)       # 62110201
d = sid % 10; print(d); sid //= 10       # 6211020
d = sid % 10; print(d); sid //= 10       # 621102
d = sid % 10; print(d); sid //= 10       # 62110
d = sid % 10; print(d); sid //= 10       # 6211
d = sid % 10; print(d); sid //= 10       # 621
d = sid % 10; print(d); sid //= 10       # 62
d = sid % 10; print(d); sid //= 10       # 6
d = sid % 10; print(d);
# Out:
# 6231020121
# 1
# 623102012
# 2
# 62310201
# 1
# 0
# 2
# 0
# 1
# 3
# 2
# 6

# %% [markdown]
# *italicized text*## Exercise: Stirling formula

# %%
import math
n = int(input())

# %% [markdown]
# **bold text**## Exercise: roots of 𝑎𝑥^2+𝑏𝑥+𝑐=0
#
# Accept key-in ```a, b, c```
# Calculate and display two roots

# %% [markdown]
# # grader 01_asdf

# %%
x = ['A','B','C','D','E']
y = x[0:1111111:2]
print(y)
# Out:
# ['A', 'C', 'E']

# %%
x = 1.0555
y = 2
y = x + y
print(y)
# Out:
# 3.0555000000000003
