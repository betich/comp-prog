# %% [markdown]
# **Question 1**
# Write program to print 50 zeros.

# %% [markdown]
# **Question 2**
# Create a variable 'count' which is a 1000-slot list. Each slot contains 0.

# %% [markdown]
# **Question 3**
# Create variable x, which is a list of integer. x has 1000 slots. The first 500 slots store 0, the rest store 1.

# %% [markdown]
# **Question 4**
# 1.   Read a string form input and store it in s.
# 2.   Print the number of characters in s.
# 3.   Read an integer from input and store it in k.
# 4.   Create a string t, that is s k times.
# 5.   Print t.

# %% [markdown]
# **Question 5**
# 1.   Create x which is a list containing 1 to 9.
# 2.   Read an integer from input and store it in k.
# 3.   Create y which is a list constructed from x k times.
# 4.   Print the length of y, followed by y (on the same line).

# %% [markdown]
# **Question 6**
# 1.   Read a string from input and store it in s.
# 2.   Connect the left most character and the rightmost character, then store the result in t.
# 3.   Store the middle character of s in variable u.
# If s = "01234" the middle character is "2". If s = "012345", the middle character is "2".

# %% [markdown]
# **Question 7**
# 1.   Use s to store a string from input.
# 2.   Store 5 leftmost characters from s in a.
# 3.   Store 5 rightmost characters from s in b.
# 4.   Store every character from s (except the leftmost and the rightmost character) in c.
# 5.   Take character number 0,2,4,...from s and store them in string d.
# 6.   Use e to store every character from s, but in reverse order.

# %% [markdown]
# **Question 8**
# 1.   Read input and store it in string s.
# 2.   Let a store s (without 2,3,4,8,9,10th characters).
# 3.   Let b store s (but change the 5th character to "+")
